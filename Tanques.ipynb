# %% [markdown]
# 1.   Luisa Fernanda Arboleda Segura CC:1.045.516.627
# 2.   Johana Catalina Rios CC:41.960.845
# 3.   Franklin Garces Usme CC: 1039024969

# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from scipy.integrate import RK45

# %% [markdown]
# ##Cuarta Tarea Modelo de TANQUES
# Tres tanques de capacidad 200 galones, tienen las siguientes condiciones, El primer tanque esta lleno hasta la mitad de salmuera, tiene 70 libras diluidas inicialmente, a este tanque entra agua pura a razón de 3 galones por minuto y de este sale a razón de 2 galones por minuto hacia el segundo tanque. Al segundo tanque, que inicialmente esta lleno hasta tres cuartos de agua pura, tiene agua pura inicialmente, le llega salmuera del primer tanque y le sale a razón de 3 galones por minuto hacia el tercer tanque la mezcla.
# Al tercer tanque, que inicialmente tiene 140 galones y 50 libras de sal diluidas, le llega la mezcla del segundo tanque y sale a razón de tres galones por minuto, la mezcla.

# %% [markdown]
# **1**. Construir un grafico que represente la situación

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **2**. Determinar las ecuaciones para cada tanque.

# %% [markdown]
# Donde C_ini:  Concentración inicial
#
# Donde f=flow1=flow2=flow3: Flujo
#
# Donde
#
# *   V00= Volúmen tanque A
# *   V01= Volúmen tanque B
# *   V02= Volúmen tanque C
#
#
#
# Analisis
#
# Datos
#
#
#
#
#   ✔ V00= 200 gal  --------  ✔A(0)=70 lib/gal
#
#   ✔ V01= 200 gal   --------  	 	 		✔B(0)=0 lib/gal
#
#   ✔V02= 200 gal  		  --------   	  ✔C(0)=50 lib/gal

# %%
def model(y,t):
  dydt=(-2*y[0]/(100+t), 2*y[0]/(100+t)-3*y[1]/(150-t), 3*y[1]/(150-t)-3*y[2]/(140))
  return dydt
y0=[70,0,50]

t=np.linspace(0,100,num=80)
y=odeint(model,y0,t)
plt.xlabel("Tiempo en minutos")
plt.ylabel("Libras de Sal")
plt.plot(t,y[:,0])
plt.plot(t,y[:,1])
plt.plot(t,y[:,2])
plt.scatter(t,y[:,0],label="Tanque A")
plt.scatter(t,y[:,1],label="Tanque B")
plt.scatter(t,y[:,2],label="Tanque C")
plt.legend()
y
# Out:
# array([[70.        ,  0.        , 50.        ],
#        [68.26093749,  1.71697371, 48.68387961],
#        [66.58588629,  3.32710466, 47.44523018],
#        [64.97174301,  4.83545484, 46.28004648],
#        [63.41559008,  6.24682294, 45.18450687],
#        [61.91468254,  7.56576155, 44.1549645 ],
#        [60.46643597,  8.79659291, 43.18793895],
#        [59.06841534,  9.94342359, 42.28010833],
#        [57.71832472, 11.010158  , 41.42830184],
#        [56.41399791, 12.00051084, 40.62949272],
#        [55.1533897 , 12.91801865, 39.88079158],
#        [53.93456787, 13.76605054, 39.17944006],
#        [52.75570578, 14.5478181 , 38.52280486],
#        [51.61507557, 15.26638455, 37.90837206],
#        [50.51104171, 15.92467343, 37.33374171],
#        [49.44205521, 16.5254765 , 36.79662273],
#        [48.40664819, 17.0714611 , 36.29482805],
#        [47.40342882, 17.56517714, 35.82626999],
#        [46.43107663, 18.00906342, 35.38895588],
#        [45.4883382 , 18.40545373, 34.98098389],
#        [44.57402306, 18.75658241, 34.60053903],
#        [43.68700001, 19.06458959, 34.24588941],
#        [42.82619352, 19.33152608, 33.91538262],
#        [41.99058055, 19.55935797, 33.6074423 ],
#        [41.17918749, 19.74997088, 33.32056488],
#        [40.39108729, 19.90517402, 33.05331647],
#        [39.62539685, 20.02670395, 32.80432988],
#        [38.88127452, 20.11622809, 32.57230179],
#        [38.15791777, 20.17534813, 32.35599005],
#        [37.45456109, 20.20560301, 32.1542111 ],
#        [36.77047391, 20.20847194, 31.9658375 ],
#        [36.10495871, 20.18537717, 31.78979559],
#        [35.45734926, 20.13768655, 31.62506325],
#        [34.82700892, 20.06671601, 31.47066771],
#        [34.21332914, 19.97373179, 31.32568355],
#        [33.61572788, 19.85995276, 31.1892307 ],
#        [33.03364835, 19.72655234, 31.06047257],
#        [32.46655762, 19.57466048, 30.93861427],
#        [31.91394545, 19.40536552, 30.82290089],
#        [31.37532313, 19.21971588, 30.71261585],
#        [30.85022239, 19.0187217 , 30.60707933],
#        [30.33819439, 18.80335639, 30.50564677],
#        [29.83880877, 18.57455811, 30.40770743],
#        [29.35165273, 18.33323112, 30.31268298],
#        [28.87633017, 18.08024712, 30.22002626],
#        [28.41246092, 17.81644651, 30.12921991],
#        [27.95967994, 17.54263949, 30.03977525],
#        [27.51763663, 17.25960729, 29.95123106],
#        [27.08599412, 16.96810313, 29.8631525 ],
#        [26.66442866, 16.66885328, 29.77513002],
#        [26.25262899, 16.36255801, 29.68677838],
#        [25.8502958 , 16.04989249, 29.59773562],
#        [25.45714114, 15.73150764, 29.50766216],
#        [25.07288792, 15.40803097, 29.41623989],
#        [24.69726944, 15.08006736, 29.32317131],
#        [24.33002891, 14.74819978, 29.22817871],
#        [23.97091901, 14.41298999, 29.13100337],
#        [23.6197015 , 14.07497925, 29.03140479],
#        [23.27614678, 13.73468892, 28.92916001],
#        [22.94003355, 13.39262107, 28.82406286],
#        [22.61114844, 13.04925908, 28.71592333],
#        [22.28928566, 12.70506816, 28.6045669 ],
#        [21.97424671, 12.36049588, 28.48983396],
#        [21.66584005, 12.01597269, 28.37157921],
#        [21.36388082, 11.67191236, 28.24967107],
#        [21.06819053, 11.32871245, 28.1239912 ],
#        [20.77859685, 10.98675473, 27.99443392],
#        [20.49493333, 10.64640561, 27.86090576],
#        [20.21703914, 10.30801649, 27.72332498],
#        [19.94475889,  9.97192415, 27.58162109],
#        [19.67794238,  9.6384511 , 27.43573447],
#        [19.4164444 ,  9.30790592, 27.2856159 ],
#        [19.16012451,  8.98058354, 27.1312262 ],
#        [18.90884691,  8.65676559, 26.97253585],
#        [18.6624802 ,  8.33672064, 26.8095246 ],
#        [18.42089725,  8.02070451, 26.64218117],
#        [18.18397499,  7.70896047, 26.4705029 ],
#        [17.95159431,  7.40171952, 26.29449542],
#        [17.72363987,  7.09920063, 26.11417239],
#        [17.49999997,  6.80161088, 25.92955519]])

# %% [markdown]
# Hacer un análisis de la situación y determinar el comportamiento de cada tanque
# después de 100 minutos:
#
# * El tanque A en un comienzo tenia alta concentracion de sal pero debido a los 3 galones de entrada de agua y los 2 galones de salida para el tanque B, queda sin salmuera.
# * El tanque B queda con toda la concentracion de sal que viene del tanque b, se espera un desbordaminto despues de 100 minutos, debido a que tanque estaba casi lleno de agua pura y la entrada de 2 galones x min.
# * El tanque C tiene mas contenido de salmuera, los 50 libras que tenia inicialmente, mas las salmuera llegada de los dos primeros tanques, no llega a desbordarse debido a los 3 galones que hay de salida.
